# %%
# summarize the horse colic dataset
from pandas import read_csv
# load dataset
dataframe = read_csv('horse-colic.csv', header=None,)
# summarize the first few rows
print(dataframe.head())
# Out:
#         0      1                2            3      4                 5   \
# 0  surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate
# 1       no  adult           530101         38.5     66                28
# 2      yes  adult           534817         39.2     88                20
# 3       no  adult           530334         38.3     40                24
# 4      yes  young          5290409         39.1    164                84
#
#                     6                 7                8   \
# 0  temp_of_extremities  peripheral_pulse  mucous_membrane
# 1                 cool           reduced              NaN
# 2                  NaN               NaN    pale_cyanotic
# 3               normal            normal        pale_pink
# 4                 cold            normal    dark_cyanotic
#
#                       9   ...                  18             19  \
# 0  capillary_refill_time  ...  packed_cell_volume  total_protein
# 1             more_3_sec  ...                  45            8.4
# 2             less_3_sec  ...                  50             85
# 3             less_3_sec  ...                  33            6.7
# 4             more_3_sec  ...                  48            7.2
#
#                   20              21          22               23        24  \
# 0  abdomo_appearance  abdomo_protein     outcome  surgical_lesion  lesion_1
# 1                NaN             NaN        died               no     11300
# 2             cloudy               2  euthanized               no      2208
# 3                NaN             NaN       lived               no         0
# 4      serosanguious             5.3        died              yes      2208
#
#          25        26       27
# 0  lesion_2  lesion_3  cp_data
# 1         0         0       no
# 2         0         0       no
# 3         0         0      yes
# 4         0         0      yes
#
# [5 rows x 28 columns]

# %%
# summarize the horse colic dataset
from pandas import read_csv
# load dataset
dataframe = read_csv('horse-colic.csv', header=None, na_values='?')
# summarize the first few rows
print(dataframe.head())
# summarize the number of rows with missing values for each column
for i in range(dataframe.shape[1]):
# count number of rows with missing values
    n_miss = dataframe[[i]].isnull().sum()
    perc = n_miss / dataframe.shape[0] * 100
print('> %d, Missing: %d (%.1f%%)' % (i, n_miss, perc))
# Out:
#         0      1                2            3      4                 5   \
# 0  surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate
# 1       no  adult           530101         38.5     66                28
# 2      yes  adult           534817         39.2     88                20
# 3       no  adult           530334         38.3     40                24
# 4      yes  young          5290409         39.1    164                84
#
#                     6                 7                8   \
# 0  temp_of_extremities  peripheral_pulse  mucous_membrane
# 1                 cool           reduced              NaN
# 2                  NaN               NaN    pale_cyanotic
# 3               normal            normal        pale_pink
# 4                 cold            normal    dark_cyanotic
#
#                       9   ...                  18             19  \
# 0  capillary_refill_time  ...  packed_cell_volume  total_protein
# 1             more_3_sec  ...                  45            8.4
# 2             less_3_sec  ...                  50             85
# 3             less_3_sec  ...                  33            6.7
# 4             more_3_sec  ...                  48            7.2
#
#                   20              21          22               23        24  \
# 0  abdomo_appearance  abdomo_protein     outcome  surgical_lesion  lesion_1
# 1                NaN             NaN        died               no     11300
# 2             cloudy               2  euthanized               no      2208
# 3                NaN             NaN       lived               no         0
# 4      serosanguious             5.3        died              yes      2208
#
#          25        26       27
# 0  lesion_2  lesion_3  cp_data
# 1         0         0       no
# 2         0         0       no
# 3         0         0      yes
# 4         0         0      yes
#
# [5 rows x 28 columns]
# > 27, Missing: 0 (0.0%)

# %%
# summarize the horse colic dataset
from pandas import read_csv
# load dataset
dataframe = read_csv('horse-colic.csv', header=None, na_values='?')
# summarize the first few rows
print(dataframe.head())
# summarize the number of rows with missing values for each column
for i in range(dataframe.shape[1]):
# count number of rows with missing values
    n_miss = dataframe[[i]].isnull().sum()
    perc = n_miss / dataframe.shape[0] * 100
    print('> %d, Missing: %d (%.1f%%)' % (i, n_miss, perc))
# Out:
#         0      1                2            3      4                 5   \
# 0  surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate
# 1       no  adult           530101         38.5     66                28
# 2      yes  adult           534817         39.2     88                20
# 3       no  adult           530334         38.3     40                24
# 4      yes  young          5290409         39.1    164                84
#
#                     6                 7                8   \
# 0  temp_of_extremities  peripheral_pulse  mucous_membrane
# 1                 cool           reduced              NaN
# 2                  NaN               NaN    pale_cyanotic
# 3               normal            normal        pale_pink
# 4                 cold            normal    dark_cyanotic
#
#                       9   ...                  18             19  \
# 0  capillary_refill_time  ...  packed_cell_volume  total_protein
# 1             more_3_sec  ...                  45            8.4
# 2             less_3_sec  ...                  50             85
# 3             less_3_sec  ...                  33            6.7
# 4             more_3_sec  ...                  48            7.2
#
#                   20              21          22               23        24  \
# 0  abdomo_appearance  abdomo_protein     outcome  surgical_lesion  lesion_1
# 1                NaN             NaN        died               no     11300
# 2             cloudy               2  euthanized               no      2208
# 3                NaN             NaN       lived               no         0
# 4      serosanguious             5.3        died              yes      2208
#
#          25        26       27
# 0  lesion_2  lesion_3  cp_data
# 1         0         0       no
# 2         0         0       no
# 3         0         0      yes
# 4         0         0      yes
#
# [5 rows x 28 columns]
# > 0, Missing: 0 (0.0%)
# > 1, Missing: 0 (0.0%)
# > 2, Missing: 0 (0.0%)
# > 3, Missing: 60 (20.0%)
# > 4, Missing: 24 (8.0%)
# > 5, Missing: 58 (19.3%)
# > 6, Missing: 56 (18.7%)
# > 7, Missing: 69 (23.0%)
# > 8, Missing: 47 (15.7%)
# > 9, Missing: 32 (10.7%)
# > 10, Missing: 55 (18.3%)
# > 11, Missing: 44 (14.7%)
# > 12, Missing: 56 (18.7%)
# > 13, Missing: 104 (34.7%)
# > 14, Missing: 106 (35.3%)
# > 15, Missing: 246 (82.0%)
# > 16, Missing: 102 (34.0%)
# > 17, Missing: 118 (39.3%)
# > 18, Missing: 29 (9.7%)
# > 19, Missing: 33 (11.0%)
# > 20, Missing: 165 (55.0%)
# > 21, Missing: 198 (66.0%)
# > 22, Missing: 0 (0.0%)
# > 23, Missing: 0 (0.0%)
# > 24, Missing: 0 (0.0%)
# > 25, Missing: 0 (0.0%)
# > 26, Missing: 0 (0.0%)
# > 27, Missing: 0 (0.0%)

# %%
# statistical imputation transform for the horse colic dataset
from numpy import isnan
from pandas import read_csv
from sklearn.impute import SimpleImputer
# load dataset
dataframe = read_csv('horse-colic.csv', header=None, na_values='?')
# split into input and output elements
data = dataframe.values
ix = [i for i in range(data.shape[1]) if i != 23]
X, y = data[:, ix], data[:, 23]
# summarize total missing
print('Missing: %d' % sum(isnan(X).flatten()))
# define imputer
imputer = SimpleImputer(strategy='mean')
# fit on the dataset
imputer.fit(X)
# transform the dataset
Xtrans = imputer.transform(X)
# summarize total missing
print('Missing: %d' % sum(isnan(Xtrans).flatten()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 12>()
#      10 X, y = data[:, ix], data[:, 23]
#      11 # summarize total missing
# ---> 12 print('Missing: %d' % sum(isnan(X).flatten()))
#      13 # define imputer
#      14 imputer = SimpleImputer(strategy='most_frequent')
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
